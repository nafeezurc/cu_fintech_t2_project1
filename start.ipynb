# %%
import fire
import questionary
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Out:
# ---------------------------------------------------------------------------
# NoConsoleScreenBufferError                Traceback (most recent call last)
# Cell In[4], line 23
#      20     answers = [name, income, word, protect, unexpected]
#      21     return answers
# ---> 23 print(customer_data())
#
# Cell In[4], line 2, in customer_data()
#       1 def customer_data():
# ----> 2     name = questionary.text("What is your name?").ask()
#       3     income = questionary.select(
#       4         "What would you consider your income level to be?",
#       5         choices=["Low","Medium","High"],
#       6     ).ask()
#       7     word = questionary.select(
#       8         "Which of the following words first comes to mind when considering risk in the financial context?",
#       9         choices=["Loss","Uncertainty","Opportunity"],
#      10     ).ask()
#
# ...
